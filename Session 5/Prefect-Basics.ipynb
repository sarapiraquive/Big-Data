# %% [markdown]
# ## Data Pipelines - Introduction to Prefect
# ### Big Data Tools
# #### M.Sc. in Applied Analytics (coterminal course)
# Fac. de Ingeniería -  Universidad de la Sabana<br>
# Prof.: Hugo Franco, Ph.D.

# %%
from prefect import flow, task, get_run_logger
from typing import Callable
from functools import wraps
import time


# Custom Timing Decorator for Prefect Tasks
def timing_decorator(func: Callable) -> Callable:
    '''Custom decorator to time task execution'''
    @wraps(func)
    def wrapper(*args, **kwargs):
        logger = get_run_logger()
        start_time = time.time()

        # Execute the original function
        result = func(*args, **kwargs)

        end_time = time.time()
        execution_time = end_time - start_time

        logger.info(f"Task '{func.__name__}' completed in {execution_time:.2f} seconds")
        return result

    return wrapper

@task
def get_users():
    return ["juan@example-mail.com", "ana@mail-example.com"]

@task
@timing_decorator
def send_email(user):
    print(f"Sending email to {user}")

@flow
def notify_users():
    users = get_users()
    for user in users:
        send_email(user)

notify_users()
# Out:
# 08:25:33.188 | INFO    | prefect - Starting temporary server on http://127.0.0.1:8023
# See https://docs.prefect.io/v3/concepts/server#how-to-guides for more information on running a dedicated Prefect server.
# 08:25:38.078 | INFO    | Flow run 'resolute-bandicoot' - Beginning flow run 'resolute-bandicoot' for flow 'notify-users'
# 08:25:38.126 | INFO    | Task run 'get_users-9b1' - Finished in state Completed()
# Sending email to juan@example-mail.com
# 08:25:38.162 | INFO    | Task run 'send_email-610' - Task 'send_email' completed in 0.00 seconds
# 08:25:38.171 | INFO    | Task run 'send_email-610' - Finished in state Completed()
# Sending email to ana@mail-example.com
# 08:25:38.261 | INFO    | Task run 'send_email-ea6' - Task 'send_email' completed in 0.00 seconds
# 08:25:38.264 | INFO    | Task run 'send_email-ea6' - Finished in state Completed()
# 08:25:38.272 | INFO    | Flow run 'resolute-bandicoot' - Finished in state Completed()
# 08:58:11.471 | ERROR   | prefect.server.services.telemetry - Failed to send telemetry: [Errno 8] nodename nor servname provided, or not known
# Shutting down telemetry service...
